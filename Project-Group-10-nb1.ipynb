# %%
# import dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import os

# %%
# Import ABS data

data = pd.read_csv("../project-1-group-10/Data/Tourism data by industry.csv")
labour_df = pd.DataFrame(data)
labour_df.dropna(inplace=True)
labour_df
# Out:
#      Tourism characteristic and connected industries   Sep-2004  Dec-2004  \
# 0                                      Accommodation       98.0      98.3
# 1      Cafes, restaurants and takeaway food services      125.2     132.3
# 2                       Clubs, pubs, taverns and bars      33.5      35.4
# 3                                     Rail transport        1.3       1.3
# 4       Road transport and transport equipment rental       6.0       6.0
# 5                     Air, water and other transport       26.4      26.9
# 6       Travel agency and information centre services      26.4      26.1
# 7                                  Cultural services        8.0       7.8
# 8                Casinos and other gambling services        3.0       2.9
# 9                      Sports and recreation services      20.2      19.7
# 10                                      Retail trade      103.0     103.0
# 11                            Education and training       35.5      36.9
# 12  Total tourism characteristic and connected ind...     486.6     496.6
# 13                               All other industries      20.5      20.7
# 14                          Total tourism filled jobs     507.1     517.3
# 15                 Total economy-wide filled jobs (c)   10610.1   10738.6
#
#     Mar-2005  Jun-2005  Sep-2005  Dec-2005  Mar-2006  Jun-2006  Sep-2006  ...  \
# 0       93.1      88.6      84.9      86.6      84.8      80.6      91.4  ...
# 1      134.9     136.2     137.7     138.2     128.3     127.4     137.8  ...
# 2       35.5      38.5      36.9      37.0      33.8      36.0      36.9  ...
# 3        1.3       1.3       1.3       1.4       1.4       1.3       1.4  ...
# 4        6.4       6.4       6.5       6.5       6.6       6.6       6.7  ...
# 5       27.8      27.8      28.1      28.5      28.9      28.6      28.9  ...
# 6       25.0      28.0      26.7      26.6      26.1      29.4      28.1  ...
# 7        8.2       8.0       8.0       7.8       7.8       8.3       8.3  ...
# 8        3.1       3.0       3.0       2.9       2.9       3.0       3.1  ...
# 9       20.9      20.2      20.0      19.9      19.9      20.7      21.4  ...
# 10     104.7     103.6     105.0     105.6     104.5     105.2     103.0  ...
# 11      36.5      36.8      37.9      37.8      37.9      37.5      38.6  ...
# 12     497.4     498.4     495.9     498.8     482.9     484.7     505.5  ...
# 13      20.7      20.8      21.1      21.3      21.4      21.4      21.8  ...
# 14     518.1     519.3     517.0     520.0     504.3     506.1     527.4  ...
# 15   10773.2   10832.5   10943.7   11026.7   11000.6   11036.3   11239.2  ...
#
#     Sep-2019  Dec-2019  Mar-2020  Jun-2020  Sep-2020  Dec-2020  Mar-2021  \
# 0       93.0     100.9      91.9      77.6      77.6      80.9      80.9
# 1      222.6     233.8     221.9     189.3     207.7     215.1     227.8
# 2       56.6      59.4      55.3      46.5      52.8      54.6      56.7
# 3        2.1       2.0       2.1       1.9       1.9       2.0       2.0
# 4        7.7       7.4       7.5       6.5       6.8       7.0       7.1
# 5       34.3      34.8      32.1      25.4      19.5      20.2      24.7
# 6       39.5      37.6      36.2      31.8      32.9      33.8      34.4
# 7       11.7      12.7      11.7       8.9       9.6       9.8      10.6
# 8        4.0       4.0       3.9       3.5       3.4       3.6       3.6
# 9       32.3      36.1      32.3      28.4      29.3      30.1      30.7
# 10     117.3     121.8     119.7     117.8     114.9     114.0     103.8
# 11      75.2      75.0      73.9      64.8      48.4      33.7      16.4
# 12     696.4     725.5     688.4     602.6     604.9     604.8     598.7
# 13      23.8      23.9      23.9      22.6      23.0      23.9      24.1
# 14     720.1     749.4     712.3     625.2     627.9     628.7     622.8
# 15   14158.1   14323.0   14212.2   13348.1   13650.4   14176.0   14228.0
#
#     Jun-2021  Sep-2021  Dec-2021
# 0       91.0      82.6      94.4
# 1      224.5     195.4     229.2
# 2       55.1      49.7      58.2
# 3        2.0       1.9       2.1
# 4        7.1       6.5       7.3
# 5       24.9      21.7      24.2
# 6       34.5      31.4      35.7
# 7        9.8       9.7      10.2
# 8        3.7       3.4       3.8
# 9       30.8      28.0      31.8
# 10     100.9      99.2     106.9
# 11       0.6       0.5       0.5
# 12     585.0     529.9     604.4
# 13      24.3      23.9      24.6
# 14     609.3     553.8     628.9
# 15   14362.2   13960.1   14613.4
#
# [16 rows x 71 columns]

# %%
# This plot will show the difference in employment figures between different sub-industries of tourism
# Create a dataframe for this plot

plot_df = labour_df.drop(labels=[12, 14,15])
plot_df.reset_index(drop=True,inplace=True)

# Define the figure
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

# Create a for loop that adds each row's data to the same plot
labels=[]
for index,row in plot_df.iterrows():
    x_axis = plot_df.columns.values.tolist()
    x_axis.pop(0)
    y_axis = plot_df.loc[index,:].values.tolist()
    y_axis.pop(0)
    labels.append(plot_df.iloc[index,0])
    plt.plot(x_axis,y_axis, linewidth=2, markersize=2)
    plt.xticks(ticks=x_axis,rotation=90)

# Customise the plot

font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 30}
plt.title("Tourism Jobs Filled, per Industry 2004-2021", fontdict=font)
plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.legend(labels,loc="upper left")
plt.show 
plt.savefig("Tourism Filled Jobs by Industry.png")

# %%
# Cafes, restaurants and takeaway food services is the industry with the most jobs pre and post covid
# This industry suffered two large drops in number of employees, but seems to have recovered these losses to almost pre-covid numbers
# Education and Training drops out of the data in a strange way. We can assume the entire Edu and Training industry didn't 
# completely shut down last year, possibly this industry is now being assessed through other metrics, making it invalid in 2021

# %%
# Create the same plot, but zoomed in on the last few years of data

plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

labels=[]
for index,row in plot_df.iterrows():
    x_axis = plot_df.columns.values.tolist()
    x_axis.pop(0)
    y_axis = plot_df.loc[index,:].values.tolist()
    y_axis.pop(0)
    labels.append(plot_df.iloc[index,0])
    plt.plot(x_axis,y_axis, linewidth=2, markersize=2)
    plt.xticks(ticks=x_axis,rotation=90)
    

font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 30}
plt.title("Tourism Jobs Filled, by Industry 2018-2021", fontdict=font)

plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.legend(labels,loc="upper left", fontsize=20)
plt.show 
plt.axis(["Mar-2018","Dec-2021",0,250])
plt.savefig("Tourism filled jobs, zoomed in.png")

# %%
# In this close up we see the Hospitality industry begins to drop after December 2019, and a more significant drop at March 2020.
# We see another drop in jobs filled at June 2021, before they pick up again after September 2021

# %%
# This plot will describe difference in employment figures for the totals of tourism jobs Australia-wide
# "Education and Traning" drops to zero in the previous data, leading me to believe an anamoly within the ABS data has occured.
# Therefore, to create this plot I will first remove Education and Training from the total tourism employment figures
        
plot_df_2 = labour_df.loc[[11,14]]
plot_df_2 = plot_df_2.drop(plot_df_2.columns[0],1)
plot_df_2

for column in plot_df_2:
    plot_df_2.loc[11,column] = (plot_df_2.loc[14,column]) - (plot_df_2.loc[11,column])
plot_df_2

# Define the figure
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

# Create plot
x_axis = plot_df_2.columns.values.tolist()
y_axis = plot_df_2.loc[11,:].values.tolist()
plt.plot(x_axis,y_axis, linewidth=2, markersize=2)
plt.xticks(ticks=x_axis,rotation=90)


# Customise the plot
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
plt.title("Tourism Jobs Filled, Totals",fontdict=font)
plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.legend(labels)
plt.show 
plt.savefig("Tourism filled jobs, totals.png")
# Out:
# /Users/alexanderpowers/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Here we see total tourism filled jobs.
# We can see that the tourism industry was reaching it's highest peak of employees yet in 2019 *create mean plot

# %%
# Create the same plot, but zoomed in on the last few years of data

plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

x_axis = plot_df_2.columns.values.tolist()
y_axis = plot_df_2.loc[11,:].values.tolist()
plt.plot(x_axis,y_axis, linewidth=2, markersize=2)
plt.xticks(ticks=x_axis,rotation=90)


font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
plt.title("Tourism Jobs Filled, Totals",fontdict=font)
plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.legend(labels,fontsize="large")

plt.show 
plt.axis(["Sep-2018","Dec-2021",400,800])

plt.savefig("Tourism filled jobs totals zoomed in.png")

# %%
# Now add a regression line, first convert dates to datetime, ordinal and numerical values
plot_2_timestamp = plot_df_2
plot_2_timestamp = pd.to_datetime(plot_df_2.columns)
plot_df_2.loc[14] = plot_2_timestamp
plot_df_2.loc[14] = plot_df_2.loc[14].map(dt.datetime.toordinal)
plot_2_linregress = pd.to_numeric(plot_df_2.loc[14])
plot_2_linregress.values

# Define the figure
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

# Create plot
x_axis = plot_df_2.columns.values.tolist()
y_axis = plot_df_2.loc[11,:].values.tolist()
plt.plot(x_axis,y_axis, linewidth=2, markersize=2)
plt.xticks(ticks=x_axis,rotation=90)

# Calculate regression line and add to plot
slope, intercept, r_value, p_value, std_err  = st.linregress(plot_2_linregress.values, y_axis)
plt.plot(x_axis,(slope*plot_2_linregress.values)+intercept,'r')

# # Customise the plot
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
plt.title("Tourism Jobs Filled, Totals",fontdict=font)
plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.show 
plt.savefig("Tourism filled jobs, totals.png")
print(f"The r value = {round(r_value,2)}")
# Out:
# The r value = 0.92

# %%
# This plot will describe the total economy wide employment figures, plus a regression line
# Import dependencies
import datetime as dt
from datetime import datetime

# Create dataframe for this plot, 
plot_df_3 = pd.DataFrame(labour_df.loc[15])
plot_df_3

# Use index of dataframe to create a new dataframe using the dates (to be used for line regression later)
date_list = pd.DataFrame(plot_df_3.index)
date_list[0] = date_list[0].str.replace("Sep","09")
date_list[0] = date_list[0].str.replace("Dec","12")
date_list[0] = date_list[0].str.replace("Mar","03")
date_list[0] = date_list[0].str.replace("Jun","06")
date_list = date_list.drop(0)
date_list

# Create a new dataframe with previous dataframe's data, converted to timestamp, then to a int64 value
date_list_2 = pd.DataFrame(columns=["Date","Timestamp"])
date_list = date_list[0].values
date_list = pd.to_datetime(date_list)
date_list
date_list_2["Date"] = date_list
date_list_2["Timestamp"] = date_list_2["Date"]
date_list_2
for i in range(len(date_list_2)):
    date_list_2["Timestamp"][i] = date_list_2["Timestamp"][i].toordinal()
date_list_2["Timestamp"] = date_list_2["Timestamp"].apply(pd.to_numeric)
date_list_2

# Define the figure 
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

# Create variables used for making the plot
labels=[plot_df_3.iloc[0,0]]

x_axis = plot_df_3.index.tolist()
x_axis.pop(0)

y_axis = plot_df_3.iloc[:,0].values.tolist()
y_axis.pop(0)

xlabels = plot_df_2.columns.tolist()
datelist = plot_df_3.index.to_list()

# Create plot
plt.plot(date_list_2["Timestamp"],y_axis, linewidth=2, markersize=2)
plt.xticks(ticks=date_list_2["Timestamp"].tolist(),rotation=90, labels=xlabels)

# Calculate regression line and r-value, and add to plot
slope, intercept, r_value, p_value, std_err  = st.linregress(date_list_2["Timestamp"], y_axis)
plt.plot(date_list_2["Timestamp"],(slope*date_list_2["Timestamp"])+intercept,'r')

# Customise the plot
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
plt.title("Total Economy-Wide Filled Jobs",fontdict=font)
plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.show 
print(f"The r value = {round(r_value,2)}")

plt.savefig("Total economy jobs.png")
# Out:
# /Users/alexanderpowers/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# The r value = 0.98

# %%
# Create the same plot, but zoomed in on the last few years of data

import datetime as dt
from datetime import datetime

plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

plot_df_3 = pd.DataFrame(labour_df.loc[15])
plot_df_3
date_list = pd.DataFrame(plot_df_3.index)
date_list[0] = date_list[0].str.replace("Sep","09")
date_list[0] = date_list[0].str.replace("Dec","12")
date_list[0] = date_list[0].str.replace("Mar","03")
date_list[0] = date_list[0].str.replace("Jun","06")
date_list.drop(0,inplace=True)

date_list_2 = pd.DataFrame(columns=["Date","Timestamp"])
date_list = date_list[0].values.tolist()
date_list = pd.to_datetime(date_list)
date_list_2["Date"] = date_list
date_list_2["Timestamp"] = date_list_2["Date"]
for i in range(len(date_list_2)):
    date_list_2["Timestamp"][i] = date_list_2["Date"][i].toordinal()
date_list_2["Timestamp"] = date_list_2["Timestamp"].apply(pd.to_numeric)
date_list_2



labels=[plot_df_3.iloc[0,0]]
x_axis = plot_df_3.index.tolist()
x_axis.pop(0)

y_axis = plot_df_3.iloc[:,0].values.tolist()
y_axis.pop(0)
y_axis

xlabels = plot_df_2.columns.tolist()

labels.append(plot_df_3.iloc[0,0])
datelist = plot_df_3.index.to_list()

date_list_2["Date"] = date_list_2["Date"].replace("00:00:00","")
plt.plot(date_list_2["Timestamp"],y_axis, linewidth=2, markersize=2)
plt.xticks(ticks=date_list_2["Timestamp"].tolist(),rotation=90, labels=xlabels)

slope, intercept, r_value, p_value, std_err  = st.linregress(date_list_2["Timestamp"], y_axis)
plt.plot(date_list_2["Timestamp"],(slope*date_list_2["Timestamp"])+intercept,".-r")


font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
plt.title("Total Economy-Wide Filled Jobs",fontdict=font)
plt.xlabel("Date")
plt.ylabel("Jobs ('000)")
plt.show 
print(f"The r value = {round(r_value,2)}")
plt.xlim(736754,738125)
plt.ylim(13000,15000)

plt.savefig("Total economy jobs zoomed in.png")
# Out:
# /Users/alexanderpowers/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# The r value = 0.98

# %%
# Add new data of monetary output from the tourism industry

file_path = "../project-1-group-10/Data/Labour data 2.csv"
gdp_df = pd.read_csv(file_path)
gdp_df.set_index("Unnamed: 0", inplace=True)


# Create dataframe, convert values into int
for i in gdp_df.columns:
    try:
        gdp_df[i] = gdp_df[i].str.replace(",","")
        gdp_df[i] = gdp_df[i].astype(int)
    except:
        pass

gdp_df
# Out:
#                                                2004-05  2005-06  2006-07  \
# Unnamed: 0
# Accommodation                                     8582     9309    10253
# Ownership of dwellings                            2265     2447     2653
# Cafes, restaurants and takeaway food services     7223     7515     8000
# Clubs, pubs, taverns and bars                     3017     3164     3375
# Rail transport                                     632      647      677
# Taxi transport                                     510      569      622
# Other road transport                              1024     1057     1115
# Air, water and other transport                   12009    13095    14117
# Transport equipment rental                        1096     1174     1284
# Travel agency and information centre services     3634     3902     4148
# Cultural services                                 1006     1004      994
# Casinos and other gambling services                540      579      617
# Sports and recreation services                    2056     2052     2027
# Automotive fuel retailing                          668      717      779
# Other retail trade                                6230     6669     7248
# Education and training                            2619     2760     3097
# All other industries                              2241     2318     2567
# Total tourism characteristic industries          43595    46516    49882
# Total tourism connected industries                9517    10146    11124
# Total direct tourism output, at basic prices     55353    58980    63573
#
#                                                2007-08  2008-09  2009-10  \
# Unnamed: 0
# Accommodation                                    11208    10665    10432
# Ownership of dwellings                            2894     3190     3350
# Cafes, restaurants and takeaway food services     8364     8292     8226
# Clubs, pubs, taverns and bars                     3589     3615     3624
# Rail transport                                     694      711      752
# Taxi transport                                     681      733      788
# Other road transport                              1148     1184     1241
# Air, water and other transport                   14287    14614    14468
# Transport equipment rental                        1299     1308     1287
# Travel agency and information centre services     4456     4748     4854
# Cultural services                                 1020     1079     1066
# Casinos and other gambling services                669      703      710
# Sports and recreation services                    2165     2390     2459
# Automotive fuel retailing                          818      825      812
# Other retail trade                                7539     7536     7350
# Education and training                            3392     3818     4100
# All other industries                              2726     2693     2671
# Total tourism characteristic industries          52473    53234    53259
# Total tourism connected industries               11749    12179    12262
# Total direct tourism output, at basic prices     66949    68106    68191
#
#                                                2010-11  2011-12  2012-13  \
# Unnamed: 0
# Accommodation                                    10800    11235    11693
# Ownership of dwellings                            3645     3896     4123
# Cafes, restaurants and takeaway food services     8463     9087     9792
# Clubs, pubs, taverns and bars                     3693     3863     4077
# Rail transport                                     750      775      809
# Taxi transport                                     810      907      931
# Other road transport                              1248     1306     1376
# Air, water and other transport                   15334    15720    15889
# Transport equipment rental                        1349     1378     1543
# Travel agency and information centre services     5090     5296     5493
# Cultural services                                 1114     1195     1291
# Casinos and other gambling services                790      858      962
# Sports and recreation services                    2575     2766     2997
# Automotive fuel retailing                          816      869      912
# Other retail trade                                7460     8010     8505
# Education and training                            4137     4182     4251
# All other industries                              2740     2949     3259
# Total tourism characteristic industries          55661    58282    60977
# Total tourism connected industries               12413    13061    13668
# Total direct tourism output, at basic prices     70815    74292    77905
#
#                                                2013-14  2014-15  2015-16  \
# Unnamed: 0
# Accommodation                                    11640    11807    12261
# Ownership of dwellings                            4299     4483     4639
# Cafes, restaurants and takeaway food services    10500    11289    12163
# Clubs, pubs, taverns and bars                     4429     4857     5336
# Rail transport                                     827      864      919
# Taxi transport                                     991     1025     1071
# Other road transport                              1411     1470     1562
# Air, water and other transport                   16697    17661    18350
# Transport equipment rental                        1586     1632     1708
# Travel agency and information centre services     5710     5981     6265
# Cultural services                                 1359     1354     1451
# Casinos and other gambling services               1013     1106     1196
# Sports and recreation services                    3202     3235     3522
# Automotive fuel retailing                          950      974     1002
# Other retail trade                                8846     9062     9330
# Education and training                            4445     4995     5823
# All other industries                              3353     3519     3660
# Total tourism characteristic industries          63664    66763    70442
# Total tourism connected industries               14241    15031    16154
# Total direct tourism output, at basic prices     81257    85314    90256
#
#                                                2016-17  2017-18  2018-19  \
# Unnamed: 0
# Accommodation                                    12306    13013    13471
# Ownership of dwellings                            4813     5004     5193
# Cafes, restaurants and takeaway food services    12782    13513    14385
# Clubs, pubs, taverns and bars                     5683     6015     6363
# Rail transport                                     941     1030     1113
# Taxi transport                                    1130     1196     1266
# Other road transport                              1600     1704     1787
# Air, water and other transport                   19559    21430    23608
# Transport equipment rental                        1749     1810     1847
# Travel agency and information centre services     6570     6903     7404
# Cultural services                                 1567     1726     1857
# Casinos and other gambling services               1234     1303     1357
# Sports and recreation services                    3874     4136     4312
# Automotive fuel retailing                         1009     1084     1141
# Other retail trade                                9357    10049    10557
# Education and training                            6946     8089     9050
# All other industries                              3945     4142     4380
# Total tourism characteristic industries          73809    78782    83963
# Total tourism connected industries               17312    19222    20748
# Total direct tourism output, at basic prices     95066   102146   109091
#
#                                                2019-20  2020-21
# Unnamed: 0
# Accommodation                                    11126     8152
# Ownership of dwellings                            5187     5163
# Cafes, restaurants and takeaway food services    11073     9631
# Clubs, pubs, taverns and bars                     4955     4102
# Rail transport                                     852      396
# Taxi transport                                     909      367
# Other road transport                              1402      752
# Air, water and other transport                   17471     6160
# Transport equipment rental                        1569     1062
# Travel agency and information centre services     5915     4328
# Cultural services                                 1501     1080
# Casinos and other gambling services               1053      770
# Sports and recreation services                    3498     2501
# Automotive fuel retailing                         1042      848
# Other retail trade                                9584     7769
# Education and training                            9989      562
# All other industries                              3323     1709
# Total tourism characteristic industries          66510    44465
# Total tourism connected industries               20615     9179
# Total direct tourism output, at basic prices     90448    55353

# %%
# This plot will describe monetary output between tourism sub-industries

# Define figure
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

# Create dataframe for this plot
plot_df_4 = gdp_df.drop(labels=["Total tourism characteristic industries","Total tourism connected industries","Total direct tourism output, at basic prices"])
plot_df_4.reset_index(drop=True,inplace=True)
plot_df_4


# Use for loop to add each row of data to the same plot

for index,row in plot_df_4.iterrows():
    x_axis = plot_df_4.columns.values.tolist()
    x_axis.pop(0)
    y_axis = plot_df_4.loc[index,:].values.tolist()
    y_axis.pop(0)
    plt.plot(x_axis,y_axis, linewidth=2, markersize=2)


# Customise the plot
labels= gdp_df.index
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
y_ticks = [0,5000,10000,15000,20000,25000,30000]
plt.xticks(ticks=x_axis,rotation=90)
plt.yticks(ticks=y_ticks)
plt.title("Direct Tourism Output per Industry, $m",fontdict=font)
plt.xlabel("Date")
plt.ylabel("$m")
plt.legend(labels,fontsize=15)
plt.show 

plt.savefig("Direct tourism output.png")

# %%
# To do: Total Tourism output
# Subplot with total tourism jobs (mean of each year)

# %%
# This plot will show total tourism output across all sub-industries

# Define the figure
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')

# Create new dataframe for this plot
plot_df_5 = pd.DataFrame(gdp_df.iloc[19,:])

# Create plot and customise
plot_df_5.plot(kind="line", figsize=(20,10))
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 60}
y_ticks = [0,5000,10000,15000,20000,25000,30000]
plt.xticks(range(0,len(plot_df_5.index)),plot_df_5.index, rotation=90)
plt.title("Total Direct Tourism Output, $m",fontdict=font)
plt.xlabel("Date")
plt.ylabel("$m")
plt.show 

plt.savefig("Direct tourism output zoomed in.png")

# %%
# This plot will display two subplots showing correlation between amount of jobs and amount of monetary output.

# Create 1st dataframe, find mean value for each year
df1 = pd.DataFrame(labour_df.loc[14])
df1.reset_index(inplace=True)
df1 = df1.drop(0,axis=0)
df1["index"] = pd.to_datetime(df1["index"])
df1 = pd.DataFrame(df1.groupby(df1['index'].map(lambda x: x.year)).mean())
df1 = df1.drop("index",axis=1)

# Create 2nd dataframe
plot_df_5["Years"] = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]
plot_df_5 = plot_df_5.set_index(plot_df_5["Years"])
plot_df_5

# Define the figure and subplots
plt.figure(figsize=(20,10))
plt.style.use('fivethirtyeight')
fig,(ax1,ax2) = plt.subplots(2, figsize=(20,10))
fig.tight_layout(h_pad=5)

# Customise the plots
ax1.plot(df1.index,df1[14],label="Total tourism filled jobs, yearly average")
ax1.set_title("Total tourism filled jobs, yearly average")
ax1.set_xlabel("Year")
ax1.set_ylabel("Jobs Filled ('000)")
ax1.set_xticks(df1.index)

ax2.plot(plot_df_5.index,plot_df_5["Total direct tourism output, at basic prices"], label="Total direct tourism output, at basic prices")
ax2.set_title("Total direct tourism output ($m)")
ax2.set_xlabel("Year")
ax2.set_ylabel("Output (m$)")
ax2.set_xticks(plot_df_5.index)


fig.suptitle("Tourism Filled Jobs (yearly average)('000) vs Direct Tourism Output ($m)", fontsize=35, weight="bold")
plt.subplots_adjust(top=0.85, bottom=0.2)
plt.savefig("Jobs vs Output.png")

# Calculate percentage of change from 2019 to 2021 for each
jobs_2019_value = df1.iloc[15,0]
jobs_2021_value = df1.iloc[17,0]
jobs_difference = jobs_2019_value - jobs_2021_value
jobs_pc_change = "{:,.2f}%".format((jobs_difference/jobs_2019_value)*100)


money_2019_value = plot_df_5.iloc[14,0]
money_2021_value = plot_df_5.iloc[16,0]
money_difference =  money_2019_value - money_2021_value
money_pc_change = "{:,.2f}%".format((money_difference/money_2019_value)*100)

# Add calculation to plot
s = f"The percentage of change for jobs is {jobs_pc_change}\n The percentage of change for monetary output is {money_pc_change}"
font = {'family' : 'sans-serif',
        'size'   : 30}
fig.text(0,0,s, fontdict=font,bbox=dict(facecolor='red', alpha=0.5))
# Out:
# Text(0, 0, 'The percentage of change for jobs is 15.59%\n The percentage of change for monetary output is 49.26%')
